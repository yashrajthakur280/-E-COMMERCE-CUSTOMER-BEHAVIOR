# %% [markdown]
# <a href="https://colab.research.google.com/github/yashrajthakur280/-E-COMMERCE-CUSTOMER-BEHAVIOR/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-20fde1f0-82eb-4523-b619-e9e675899b0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20fde1f0-82eb-4523-b619-e9e675899b0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("Ecommerce.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 25000
# Columns: 29

# %%
df.head()
# Out:
#    customer_id  session_id  visit_date  device_type  user_type  \
# 0         1803           0  28-11-2024            2          1
# 1         7964           1  25-09-2024            2          0
# 2         6890           2  31-05-2024            1          1
# 3         4949           3  30-01-2024            1          0
# 4         4896           4  25-02-2024            1          1
#
#    marketing_channel  product_id  product_category  unit_price  quantity  \
# 0                  2         894                 6      651.57         1
# 1                  4         844                 2      945.27         4
# 2                  0         865                 0      400.44         4
# 3                  2         851                 3     1268.54         2
# 4                  5         794                 3      880.81         3
#
#    discount_percent  discount_amount  revenue  pages_viewed  time_on_site_sec  \
# ...

# %%
df.columns.tolist()
# Out:
# ['customer_id',
#  'session_id',
#  'visit_date',
#  'device_type',
#  'user_type',
#  'marketing_channel',
#  'product_id',
#  'product_category',
#  'unit_price',
#  'quantity',
#  'discount_percent',
#  'discount_amount',
#  'revenue',
#  'pages_viewed',
#  'time_on_site_sec',
#  'added_to_cart',
#  'purchased',
#  'cart_abandoned',
#  'rating',
#  'review_text',
#  'review_helpful_votes',
#  'payment_method',
#  'visit_day',
#  'visit_month',
#  'visit_weekday',
#  'visit_season',
#  'session_duration_bucket',
#  'revenue_normalized',
#  'location']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              25000 non-null  int64
#  1   session_id               25000 non-null  int64
#  2   visit_date               25000 non-null  object
#  3   device_type              25000 non-null  int64
#  4   user_type                25000 non-null  int64
#  5   marketing_channel        25000 non-null  int64
#  6   product_id               25000 non-null  int64
#  7   product_category         25000 non-null  int64
#  8   unit_price               25000 non-null  float64
#  9   quantity                 25000 non-null  int64
#  10  discount_percent         25000 non-null  int64
#  11  discount_amount          25000 non-null  float64
#  12  revenue                  25000 non-null  float64
#  13  pages_viewed             25000 non-null  int64
# ...

# %%
df.describe()
# Out:
#         customer_id    session_id   device_type     user_type  \
# count  25000.000000  25000.000000  25000.000000  25000.000000
# mean    5479.930600  12499.500000      0.705040      0.551280
# std     2593.544596   7217.022701      0.639543      0.497373
# min     1000.000000      0.000000      0.000000      0.000000
# 25%     3234.000000   6249.750000      0.000000      0.000000
# 50%     5482.000000  12499.500000      1.000000      1.000000
# 75%     7715.000000  18749.250000      1.000000      1.000000
# max     9998.000000  24999.000000      2.000000      1.000000
#
#        marketing_channel    product_id  product_category    unit_price  \
# count       25000.000000  25000.000000      25000.000000  25000.000000
# mean            2.514040    449.107000          3.495240    782.319010
# std             1.704934    259.513787          2.285053    476.612168
# min             0.000000      0.000000          0.000000     50.050000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                0
# session_id                 0
# visit_date                 0
# device_type                0
# user_type                  0
# marketing_channel          0
# product_id                 0
# product_category           0
# unit_price                 0
# quantity                   0
# discount_percent           0
# discount_amount            0
# revenue                    0
# pages_viewed               0
# time_on_site_sec           0
# added_to_cart              0
# purchased                  0
# cart_abandoned             0
# rating                     0
# review_text                0
# review_helpful_votes       0
# payment_method             0
# visit_day                  0
# visit_month                0
# visit_weekday              0
# visit_season               0
# session_duration_bucket    0
# revenue_normalized         0
# location                   0
# dtype: int64

# %%
missing = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': (df.isnull().sum() / len(df)) * 100
})

missing.sort_values(
    by='Missing Values',
    ascending=False
)
# Out:
#                          Missing Values  Percentage
# customer_id                           0         0.0
# session_id                            0         0.0
# visit_date                            0         0.0
# device_type                           0         0.0
# user_type                             0         0.0
# marketing_channel                     0         0.0
# product_id                            0         0.0
# product_category                      0         0.0
# unit_price                            0         0.0
# quantity                              0         0.0
# discount_percent                      0         0.0
# discount_amount                       0         0.0
# revenue                               0         0.0
# pages_viewed                          0         0.0
# time_on_site_sec                      0         0.0
# added_to_cart                         0         0.0
# purchased                             0         0.0
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df = df.drop_duplicates()

print("New dataset shape:", df.shape)
# Out:
# New dataset shape: (25000, 29)

# %%
df.dtypes
# Out:
# customer_id                  int64
# session_id                   int64
# visit_date                  object
# device_type                  int64
# user_type                    int64
# marketing_channel            int64
# product_id                   int64
# product_category             int64
# unit_price                 float64
# quantity                     int64
# discount_percent             int64
# discount_amount            float64
# revenue                    float64
# pages_viewed                 int64
# time_on_site_sec             int64
# added_to_cart                int64
# purchased                    int64
# cart_abandoned               int64
# rating                       int64
# review_text                  int64
# review_helpful_votes         int64
# payment_method               int64
# visit_day                    int64
# visit_month                  int64
# visit_weekday                int64
# visit_season                 int64
# session_duration_bucket     object
# ...

# %%
df['visit_date'] = pd.to_datetime(
    df['visit_date'],
    errors='coerce'
)

print(df['visit_date'].dtype)
# Out:
# datetime64[ns]
# /tmp/ipykernel_5528/3909664029.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['visit_date'] = pd.to_datetime(

# %%
print("Invalid dates:", df['visit_date'].isnull().sum())
# Out:
# Invalid dates: 0

# %%
print("Negative Revenue:",
      (df['revenue'] < 0).sum())

print("Negative Quantity:",
      (df['quantity'] < 0).sum())

print("Negative Unit Price:",
      (df['unit_price'] < 0).sum())
# Out:
# Negative Revenue: 0
# Negative Quantity: 0
# Negative Unit Price: 0

# %%
total_customers = df['customer_id'].nunique()
total_sessions = df['session_id'].nunique()
total_revenue = df['revenue'].sum()
average_revenue = df['revenue'].mean()

print("Total Customers:", total_customers)
print("Total Sessions:", total_sessions)
print("Total Revenue:", round(total_revenue, 2))
print("Average Revenue:", round(average_revenue, 2))
# Out:
# Total Customers: 8442
# Total Sessions: 25000
# Total Revenue: 10116169.06
# Average Revenue: 404.65

# %%
customer_summary = df.groupby('customer_id').agg(
    total_sessions=('session_id', 'nunique'),
    total_revenue=('revenue', 'sum'),
    average_revenue=('revenue', 'mean'),
    total_quantity=('quantity', 'sum'),
    total_purchases=('purchased', 'sum')
).reset_index()

customer_summary.head()
# Out:
#    customer_id  total_sessions  total_revenue  average_revenue  \
# 0         1000               2        1228.72       614.360000
# 1         1001               1           0.00         0.000000
# 2         1002               3           0.00         0.000000
# 3         1003               3        1681.96       560.653333
# 4         1004               3           0.00         0.000000
#
#    total_quantity  total_purchases
# 0               7                1
# 1               4                0
# 2               8                0
# 3               9                1
# 4               5                0

# %%
top_customers = customer_summary.sort_values(
    'total_revenue',
    ascending=False
)

top_customers.head(10)
# Out:
#       customer_id  total_sessions  total_revenue  average_revenue  \
# 3940         5176               6       15955.15      2659.191667
# 704          1738               3       13800.96      4600.320000
# 1878         2994               6       12989.28      2164.880000
# 6185         7574               4       12451.97      3112.992500
# 318          1334               8       12203.21      1525.401250
# 481          1506               5       11867.10      2373.420000
# 2493         3645               4       11806.82      2951.705000
# 6344         7744               5       11728.23      2345.646000
# 2833         4004               4       11708.76      2927.190000
# 4949         6256               7       11609.37      1658.481429
#
#       total_quantity  total_purchases
# 3940              13                4
# 704                9                3
# 1878              20                3
# 6185              13                2
# 318               18                5
# ...

# %%
top10 = top_customers.head(10)

plt.figure(figsize=(10,6))

plt.bar(
    top10['customer_id'].astype(str),
    top10['total_revenue']
)

plt.title("Top 10 Customers by Revenue")
plt.xlabel("Customer ID")
plt.ylabel("Revenue")
plt.xticks(rotation=45)

plt.show()

# %%
category_revenue = df.groupby(
    'product_category'
)['revenue'].sum().sort_values(
    ascending=False
)

category_revenue
# Out:
# product_category
# 2    2037576.79
# 6    1930885.22
# 5    1729167.16
# 3    1293649.90
# 7    1089617.52
# 0     880077.03
# 1     702788.87
# 4     452406.57
# Name: revenue, dtype: float64

# %%
category_quantity = df.groupby(
    'product_category'
)['quantity'].sum().sort_values(
    ascending=False
)

category_quantity
# Out:
# product_category
# 2    8019
# 4    7959
# 5    7949
# 6    7765
# 0    7730
# 7    7688
# 3    7582
# 1    7534
# Name: quantity, dtype: int64

# %%
category_revenue = df.groupby(
    'product_category'
)['revenue'].sum().sort_values(
    ascending=False
)

print("Category Revenue:")
print(category_revenue)
# Out:
# Category Revenue:
# product_category
# 2    2037576.79
# 6    1930885.22
# 5    1729167.16
# 3    1293649.90
# 7    1089617.52
# 0     880077.03
# 1     702788.87
# 4     452406.57
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(10,6))

category_revenue.plot(kind='bar')

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.xticks(rotation=45)

plt.show()

# %%
product_analysis = df.groupby('product_id').agg(
    total_quantity=('quantity', 'sum'),
    total_revenue=('revenue', 'sum'),
    sessions=('session_id', 'nunique')
).reset_index()

product_analysis.head()
# Out:
#    product_id  total_quantity  total_revenue  sessions
# 0           0              78        9483.18        32
# 1           1              80        6943.91        28
# 2           2              69       15760.13        27
# 3           3              71       12931.62        27
# 4           4              56        4693.52        22

# %%
top_products = product_analysis.sort_values(
    'total_revenue',
    ascending=False
)

top_products.head(10)
# Out:
#      product_id  total_quantity  total_revenue  sessions
# 130         130              67       35975.88        29
# 292         292             105       33794.75        41
# 806         806              86       32446.56        32
# 49           49              85       32122.48        31
# 453         453              66       31456.73        27
# 696         696             108       30775.59        41
# 175         175              85       30099.90        34
# 686         686             104       30001.75        43
# 634         634              75       29627.73        29
# 755         755              75       28377.64        29

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d4cb440-08db-4306-bdab-b4a8cbd97824" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d4cb440-08db-4306-bdab-b4a8cbd97824">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Ecommerce.csv")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Dataset loaded successfully!
# Rows: 25000
# Columns: 29

# %%
df.head()
# Out:
#    customer_id  session_id  visit_date  device_type  user_type  \
# 0         1803           0  28-11-2024            2          1
# 1         7964           1  25-09-2024            2          0
# 2         6890           2  31-05-2024            1          1
# 3         4949           3  30-01-2024            1          0
# 4         4896           4  25-02-2024            1          1
#
#    marketing_channel  product_id  product_category  unit_price  quantity  ...  \
# 0                  2         894                 6      651.57         1  ...
# 1                  4         844                 2      945.27         4  ...
# 2                  0         865                 0      400.44         4  ...
# 3                  2         851                 3     1268.54         2  ...
# 4                  5         794                 3      880.81         3  ...
#
#    review_text  review_helpful_votes  payment_method  visit_day  visit_month  \
# ...

# %%
purchase_counts = df['purchased'].value_counts()

print(purchase_counts)
# Out:
# purchased
# 0    19384
# 1     5616
# Name: count, dtype: int64

# %%
conversion_rate = df['purchased'].mean() * 100

print("Conversion Rate:", round(conversion_rate, 2), "%")
# Out:
# Conversion Rate: 22.46 %

# %%
df = pd.read_csv("Ecommerce.csv")

# %%
df['purchased']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 24995    0
# 24996    0
# 24997    0
# 24998    0
# 24999    0
# Name: purchased, Length: 25000, dtype: int64

# %%
cart_abandonment_rate = (
    df['cart_abandoned'].mean() * 100
)

print(
    "Cart Abandonment Rate:",
    round(cart_abandonment_rate, 2),
    "%"
)
# Out:
# Cart Abandonment Rate: 42.0 %

# %%
add_to_cart_rate = (
    df['added_to_cart'].mean() * 100
)

print(
    "Add-to-Cart Rate:",
    round(add_to_cart_rate, 2),
    "%"
)
# Out:
# Add-to-Cart Rate: 64.47 %

# %%
customer_visits = df.groupby(
    'customer_id'
)['session_id'].nunique()

one_time_customers = (
    customer_visits == 1
).sum()

repeat_customers = (
    customer_visits > 1
).sum()

print("One-Time Customers:", one_time_customers)
print("Repeat Customers:", repeat_customers)
# Out:
# One-Time Customers: 1524
# Repeat Customers: 6918

# %%
repeat_percentage = (
    repeat_customers /
    len(customer_visits)
) * 100

print(
    "Repeat Customer Percentage:",
    round(repeat_percentage, 2),
    "%"
)
# Out:
# Repeat Customer Percentage: 81.95 %

# %%
payment_counts = df[
    'payment_method'
].value_counts()

payment_counts
# Out:
# payment_method
# 1    4281
# 4    4229
# 0    4227
# 3    4140
# 5    4072
# 2    4051
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))

payment_counts.plot(kind='bar')

plt.title("Payment Method Usage")
plt.xlabel("Payment Method")
plt.ylabel("Number of Sessions")

plt.show()

# %%
daily_revenue = df.groupby(
    'visit_date'
)['revenue'].sum()

daily_revenue.head()
# Out:
# visit_date
# 2024-01-01    46931.67
# 2024-01-02    16286.60
# 2024-01-03    30361.29
# 2024-01-04    41447.56
# 2024-01-05    16344.67
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.plot(
    daily_revenue.index,
    daily_revenue.values
)

plt.title("Revenue Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Revenue")

plt.xticks(rotation=45)

plt.show()

# %%
device_revenue = df.groupby(
    'device_type'
)['revenue'].sum().sort_values(
    ascending=False
)

device_revenue
# Out:
# device_type
# 1    5006533.74
# 0    4077146.03
# 2    1032489.29
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))

device_revenue.plot(kind='bar')

plt.title("Revenue by Device Type")
plt.xlabel("Device Type")
plt.ylabel("Revenue")

plt.show()

# %%
marketing_analysis = df.groupby(
    'marketing_channel'
).agg(
    sessions=('session_id', 'nunique'),
    revenue=('revenue', 'sum'),
    purchases=('purchased', 'sum')
)

marketing_analysis
# Out:
#                    sessions     revenue  purchases
# marketing_channel
# 0                      4041  1661328.76        918
# 1                      4190  1646768.68        927
# 2                      4281  1711962.69        943
# 3                      4116  1675463.47        932
# 4                      4109  1599821.67        890
# 5                      4263  1820823.79       1006

# %%
marketing_conversion = (
    df.groupby('marketing_channel')['purchased']
    .mean() * 100
)

marketing_conversion
# Out:
# marketing_channel
# 0    22.717149
# 1    22.124105
# 2    22.027564
# 3    22.643343
# 4    21.659771
# 5    23.598405
# Name: purchased, dtype: float64

# %%
plt.figure(figsize=(10,6))

marketing_conversion.plot(kind='bar')

plt.title("Conversion Rate by Marketing Channel")
plt.xlabel("Marketing Channel")
plt.ylabel("Conversion Rate (%)")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(
    customer_summary['total_revenue'],
    bins=30
)

plt.title("Customer Spending Distribution")
plt.xlabel("Total Customer Revenue")
plt.ylabel("Number of Customers")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    customer_summary['total_sessions'],
    customer_summary['total_revenue'],
    alpha=0.5
)

plt.title("Purchase Frequency vs Customer Spending")
plt.xlabel("Number of Sessions")
plt.ylabel("Total Revenue")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    customer_summary['total_sessions'],
    customer_summary['total_revenue'],
    alpha=0.5
)

plt.title("Purchase Frequency vs Customer Spending")
plt.xlabel("Number of Sessions")
plt.ylabel("Total Revenue")

plt.show()

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    correlation,
    annot=True,
    fmt='.2f'
)

plt.title("Correlation Heatmap")

plt.show()

# %%
max_date = df['visit_date'].max()

print("Latest Date:", max_date)
# Out:
# Latest Date: 2024-12-30 00:00:00

# %%
rfm = df.groupby('customer_id').agg(
    Recency=(
        'visit_date',
        lambda x: (max_date - x.max()).days
    ),

    Frequency=(
        'session_id',
        'nunique'
    ),

    Monetary=(
        'revenue',
        'sum'
    )
).reset_index()

rfm.head()
# Out:
#    customer_id  Recency  Frequency  Monetary
# 0         1000      195          2   1228.72
# 1         1001        9          1      0.00
# 2         1002       56          3      0.00
# 3         1003       26          3   1681.96
# 4         1004       94          3      0.00

# %%
rfm['R_Score'] = pd.qcut(
    rfm['Recency'].rank(method='first'),
    4,
    labels=[4,3,2,1]
)

rfm['F_Score'] = pd.qcut(
    rfm['Frequency'].rank(method='first'),
    4,
    labels=[1,2,3,4]
)

rfm['M_Score'] = pd.qcut(
    rfm['Monetary'].rank(method='first'),
    4,
    labels=[1,2,3,4]
)

rfm.head()
# Out:
#    customer_id  Recency  Frequency  Monetary R_Score F_Score M_Score
# 0         1000      195          2   1228.72       1       1       3
# 1         1001        9          1      0.00       4       1       1
# 2         1002       56          3      0.00       3       2       1
# 3         1003       26          3   1681.96       4       2       3
# 4         1004       94          3      0.00       2       2       1

# %%
rfm['RFM_Score'] = (
    rfm['R_Score'].astype(str) +
    rfm['F_Score'].astype(str) +
    rfm['M_Score'].astype(str)
)

rfm.head()
# Out:
#    customer_id  Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score
# 0         1000      195          2   1228.72       1       1       3       113
# 1         1001        9          1      0.00       4       1       1       411
# 2         1002       56          3      0.00       3       2       1       321
# 3         1003       26          3   1681.96       4       2       3       423
# 4         1004       94          3      0.00       2       2       1       221

# %%
def customer_segment(row):

    if (
        row['R_Score'] >= 3 and
        row['F_Score'] >= 3 and
        row['M_Score'] >= 3
    ):
        return 'High Value'

    elif (
        row['F_Score'] >= 3 and
        row['M_Score'] >= 3
    ):
        return 'Regular'

    elif row['R_Score'] >= 3:
        return 'Recent'

    elif (
        row['R_Score'] <= 2 and
        row['F_Score'] <= 2
    ):
        return 'Low Value'

    else:
        return 'Occasional'


rfm['Segment'] = rfm.apply(
    customer_segment,
    axis=1
)

rfm.head()
# Out:
#    customer_id  Recency  Frequency  Monetary R_Score F_Score M_Score  \
# 0         1000      195          2   1228.72       1       1       3
# 1         1001        9          1      0.00       4       1       1
# 2         1002       56          3      0.00       3       2       1
# 3         1003       26          3   1681.96       4       2       3
# 4         1004       94          3      0.00       2       2       1
#
#   RFM_Score    Segment
# 0       113  Low Value
# 1       411     Recent
# 2       321     Recent
# 3       423     Recent
# 4       221  Low Value

# %%
segment_counts = rfm[
    'Segment'
].value_counts()

segment_counts
# Out:
# Segment
# Low Value     2719
# Recent        2422
# High Value    1799
# Regular        908
# Occasional     594
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))

segment_counts.plot(kind='bar')

plt.title("Customer Segment Distribution")
plt.xlabel("Customer Segment")
plt.ylabel("Number of Customers")

plt.show()

# %%
segment_revenue = rfm.groupby(
    'Segment'
)['Monetary'].sum().sort_values(
    ascending=False
)

segment_revenue
# Out:
# Segment
# High Value    4788764.51
# Regular       2344754.97
# Low Value     1849513.57
# Recent        1133136.01
# Occasional          0.00
# Name: Monetary, dtype: float64

# %%
plt.figure(figsize=(10,6))

segment_revenue.plot(kind='bar')

plt.title("Revenue by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Revenue")

plt.show()

# %%
print("========== BUSINESS INSIGHTS ==========")

print(
    "Total Customers:",
    df['customer_id'].nunique()
)

print(
    "Total Sessions:",
    df['session_id'].nunique()
)

print(
    "Total Revenue:",
    round(df['revenue'].sum(), 2)
)

print(
    "Conversion Rate:",
    round(df['purchased'].mean() * 100, 2),
    "%"
)

print(
    "Cart Abandonment Rate:",
    round(df['cart_abandoned'].mean() * 100, 2),
    "%"
)

print(
    "Highest Revenue Category:",
    category_revenue.idxmax()
)

print(
    "Most Used Payment Method:",
    payment_counts.idxmax()
)

print(
    "Largest Customer Segment:",
    segment_counts.idxmax()
)
# Out:
# ========== BUSINESS INSIGHTS ==========
# Total Customers: 8442
# Total Sessions: 25000
# Total Revenue: 10116169.06
# Conversion Rate: 22.46 %
# Cart Abandonment Rate: 42.0 %
# Highest Revenue Category: 2
# Most Used Payment Method: 1
# Largest Customer Segment: Low Value

# %%
df.to_csv(
    "Ecommerce_Cleaned.csv",
    index=False
)

rfm.to_csv(
    "Customer_RFM_Segmentation.csv",
    index=False
)

print("Files saved successfully!")
# Out:
# Files saved successfully!

# %%
from google.colab import files

files.download("Ecommerce_Cleaned.csv")

# %%
files.download("Customer_RFM_Segmentation.csv")
